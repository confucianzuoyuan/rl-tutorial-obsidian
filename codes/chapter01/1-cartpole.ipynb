# %%
import numpy as np
import gym
import time
import matplotlib.pyplot as plt
from IPython.display import clear_output

env = gym.make('CartPole-v0')
state = env.reset()
done = False
action_desc = {0: "向左推", 1: "向右推"}
total_reward = 0.0
reward_list = []
gamma = 0.99

while not done:
    # 清除cell的输出
    # clear_output(wait=True)
    plt.imshow(env.render(mode='rgb_array'))
    plt.show()
    action = np.random.choice([0, 1])
    next_state, reward, done, info = env.step(action)
    print(
        f"采取动作：{action_desc.get(action, '未知动作')}，获得奖励：{reward}，转移到下一个状态：{next_state}")
    reward_list.append(reward)
    time.sleep(0.1)

# 这里要注意回报是如何逆序计算的
for r in reward_list[::-1]:
    total_reward = r + gamma * total_reward

print('回报（收益）：', total_reward)
env.close()
# Out:
# /home/zuoyuan/anaconda3/lib/python3.12/site-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# /home/zuoyuan/anaconda3/lib/python3.12/site-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /home/zuoyuan/anaconda3/lib/python3.12/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /home/zuoyuan/anaconda3/lib/python3.12/site-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# /home/zuoyuan/anaconda3/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[-0.02464299  0.21542868  0.01946429 -0.25574046]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[-0.02033442  0.41026738  0.01434948 -0.542221  ]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[-0.01212907  0.21494673  0.00350506 -0.24505161]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[-0.00783014  0.41001844 -0.00139597 -0.5366269 ]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[ 3.7023347e-04  6.0516000e-01 -1.2128509e-02 -8.2974935e-01]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[ 0.01247343  0.8004456  -0.0287235  -1.1262219 ]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[ 0.02848235  0.6057116  -0.05124794 -0.8426849 ]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[ 0.04059658  0.41132516 -0.06810163 -0.5665484 ]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[ 0.04882308  0.60733306 -0.0794326  -0.8798851 ]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[ 0.06096974  0.41337493 -0.0970303  -0.61319387]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[ 0.06923724  0.21973325 -0.10929418 -0.35257983]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[ 0.07363191  0.4162259  -0.11634578 -0.67762876]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[ 0.08195642  0.22289613 -0.12989835 -0.42372313]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[ 0.08641434  0.41959593 -0.13837281 -0.7543699 ]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[ 0.09480627  0.6163267  -0.1534602  -1.0871973 ]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[ 0.1071328   0.42352453 -0.17520416 -0.8463332 ]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[ 0.11560329  0.62054825 -0.19213082 -1.1885912 ]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[ 0.12801425  0.8175695  -0.21590264 -1.5348248 ]
# 回报（收益）： 16.54862385499124
